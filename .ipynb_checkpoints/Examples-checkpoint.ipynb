# %% [markdown]
# # MyMethods.jl -- Examples
#
# This notebook illustrates basic functionalities of the MyMethods.jl package.

# %% [markdown]
# ### Installation and Uninstallation of MyMethods.jl

# %%
# Install the package from GitHub (first time only) 
using Pkg; 
Pkg.add(url="https://github.com/thomaswiemann/MyMethods.jl");

# Uninstall 
#Pkg.rm("MyMethods")
# Out:
#    Updating git-repo `https://github.com/thomaswiemann/MyMethods.jl`
# Fetching: [========================================>]  100.0 %
#    Updating registry at `C:\Users\thomas\.julia\registries\General`
# package `MyMethods [18de7e97]` has same name or UUID as the active project
#
# Stacktrace:
#  [1] pkgerror(::String) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\Types.jl:52
#  [2] add(::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}; preserve::Pkg.Types.PreserveLevel, platform::Pkg.BinaryPlatforms.Windows, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:181
#  [3] add(::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:139
#  [4] #add#21 at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:67 [inlined]
#  [5] add at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:67 [inlined]
#  [6] #add#19 at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:65 [inlined]
#  [7] add at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:65 [inlined]
#  [8] add(; name::Nothing, uuid::Nothing, version::Nothing, url::String, rev::Nothing, path::Nothing, mode::Pkg.Types.PackageMode, subdir::Nothing, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at D:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\Pkg\src\API.jl:82
#  [9] top-level scope at In[1]:3
#  [10] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [11] execute_code(::String, ::String) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [12] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [13] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [14] invokelatest at .\essentials.jl:709 [inlined]
#  [15] eventloop(::ZMQ.Socket) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [16] (::IJulia.var"#15#18")() at .\task.jl:356

# %%
# Load MyMethods.jl into your Julia session 
using MyMethods
# Out:
# ┌ Info: Precompiling MyMethods [18de7e97-ce2a-4ea9-8d3b-e4b0c3b0b515]
# └ @ Base loading.jl:1278
# ┌ Warning: Package MyMethods does not have DataFrames in its dependencies:
# │ - If you have MyMethods checked out for development and have
# │   added DataFrames as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with MyMethods
# └ Loading DataFrames into MyMethods from project dependency, future warnings for MyMethods are suppressed.

# %%
# Load additionally useful (but not necessary) packages
using Statistics # for a quantile function
using Plots; plotly() # for a plotting backend
# Out:
# ┌ Info: For saving to png with the Plotly backend PlotlyBase has to be installed.
# └ @ Plots C:\Users\thomas\.julia\packages\Plots\D7Ica\src\backends.jl:373
# Plots.PlotlyBackend()

# %% [markdown]
# ### Exemplary Data
#
# Generate basic data to be used in the examples.

# %%
# Data parameters
N = 10000 # sample size
beta = [1,2,-1,4] # regression coefficients

# Data
_r = (1 .+ 1.5 .* (rand(N) .- 0.5)) # running variable
X = hcat(ones(N), rand(N,3)) # regressor matrix
y = X*beta.*_r + randn(N) # outcome simulation
# Out:
# 10000-element Array{Float64,1}:
#  11.78367408139462
#   0.3683626477989679
#   4.172372718740834
#   2.349739701381286
#   0.7467047097422491
#   4.664548017250035
#   5.504031687982217
#   5.107816357778589
#   2.013015467815926
#   2.0070279299738254
#   2.583894848584853
#   1.4977323026832603
#   4.8225191452993945
#   ⋮
#   1.877760216090623
#   2.7309920626274717
#   3.4288103602332844
#   3.200904654213252
#   2.2433482984283675
#   7.635140974354565
#   5.045731631878553
#   4.245184476341436
#   0.2556857014151921
#   3.4488523774815114
#   3.844638905510459
#  -0.029567061265757477

# %% [markdown]
# ### myLS
# myLS() generates a (weighted) least squares object.

# %%
# Estimate least squares fit
fit_LS = myLS(y, X);

# %%
# Calculate and print standard errors
inference(fit_LS);
# Out:
# 4×4 DataFrame
# │ Row │ coef      │ se        │ t-stat   │ p-val       │
# │     │ Float64   │ Float64   │ Float64  │ Float64     │
# ├─────┼───────────┼───────────┼──────────┼─────────────┤
# │ 1   │ 0.955292  │ 0.0602235 │ 15.8625  │ 1.15295e-56 │
# │ 2   │ 1.96151   │ 0.0660663 │ 29.69    │ 1.033e-193  │
# │ 3   │ -0.941117 │ 0.0659012 │ -14.2807 │ 2.88529e-46 │
# │ 4   │ 4.04962   │ 0.0658136 │ 61.5317  │ 0.0         │

# %% [markdown]
# ### myLLR
# myLLR generates a local linear regression object.

# %%
# Estimate local constant regression with bandwidth h = 0.4
fit_LLR = myLLR(y, _r, # response and running variable
    X[:, 2:end],# additional variables to include
    _x = quantile(_r, collect(1:100)./100), # values at which to fit
    K=0, h=0.4); # degree and bandwidth

### continue from here
## revert pack to loadpath for easier debugging

# %%
# Calculate the local coefficients for quantiles of the running variable
coef_LLR = coef(fit_LLR);

# %%
# Plot coefficients as a function of the running variable
plot(fit_LLR._x, coef_LLR,
title = "Local linear regression coefficients",
label = ["Const." "X1" "X2" "X3"])
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="6e0e672e-21a8-43a8-8e57-57654ad5b513" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('6e0e672e-21a8-43a8-8e57-57654ad5b513');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             0.2661261317504526,
#             0.28175181032909435,
#             0.2979442665308603,
#             0.31268975338036253,
#             0.32965805630541883,
#             0.34421265955857083,
#             0.35855353151800673,
#             0.3725506064909043,
#             0.3887167692607244,
#             0.4056400334319671,
#             0.4203775715906681,
#             0.4364693093297701,
#             0.45021011676471623,
#             0.4647907649397469,
#             0.4795049135575319,
#             0.4943112917474251,
#             0.5082376677869512,
#             0.523963954432056,
#             0.5388255961010133,
#             0.5538776230105985,
#             0.5694535772921645,
#             0.5859817957865822,
#             0.6025533990469685,
#             0.6162519365929974,
#             0.6316251083170646,
#             0.6478201391674775,
#             0.6626411053304813,
#             0.678079279519633,
#             0.6941374943160531,
#             0.7080961573421879,
#             0.724266014280952,
#             0.7391315032889813,
#             0.7556750817714397,
#             0.7715526470519299,
#             0.7854035350198965,
#             0.8011613870392219,
#             0.8151846953382669,
#             0.827587838085876,
#             0.8413951480648736,
#             1.2253729939047555,
#             1.237137468205394,
#             1.2493332383682785,
#             1.2586054059715914,
#             1.270742815798222,
#             1.2808499403870932,
#             1.2929100794680293,
#             1.3059510842188404,
#             1.3222410595863645,
#             1.3391830122379111,
#             1.3502776927522786,
#             1.364494530920014,
#             1.3770128945967486,
#             1.3895829661795733,
#             1.3985829471741247,
#             1.4073430352499767,
#             1.4145654803642624,
#             1.4213829611864357,
#             1.4274428619382702,
#             1.4340581050251417,
#             1.440587791964215,
#             1.448311403394183,
#             1.4558972420975564,
#             1.4616994714003937,
#             1.4673700628505681,
#             1.471573755310886,
#             1.4750569665471502,
#             1.4806515207581747,
#             1.4881842849284102,
#             1.4946353353685693,
#             1.4989987122825865,
#             1.5055117701993634,
#             1.5133546222510776,
#             1.519173094526985,
#             1.5249675152351665,
#             1.5314863869976256,
#             1.5381375260529884,
#             1.5435763462011338,
#             1.5523050498801811
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             0.2661261317504526,
#             0.28175181032909435,
#             0.2979442665308603,
#             0.31268975338036253,
#             0.32965805630541883,
#             0.34421265955857083,
#             0.35855353151800673,
#             0.3725506064909043,
#             0.3887167692607244,
#             0.4056400334319671,
#             0.4203775715906681,
#             0.4364693093297701,
#             0.45021011676471623,
#             0.4647907649397469,
#             0.4795049135575319,
#             0.4943112917474251,
#             0.50823766778

# %% [markdown]
# # mybootstrap

# %%
# bootstrap myLS
res = mybootstrap(myLS, y, 100, X, data_args = [1], 
    get = coef, red = hcat∘vcat);

# %%
# bootstrap myLLR
res = mybootstrap(myLLR, y, 10, _r, data_args = [1],
    get = coef) # think about bootstrapping myLLR!
# Out:
# MethodError: no method matching Array{Float64,1}(::Array{Float64,2})
# Closest candidates are:
#   Array{Float64,1}(::AbstractArray{S,N}) where {T, N, S} at array.jl:562
#   Array{Float64,1}() where T at boot.jl:425
#   Array{Float64,1}(!Matched::UndefInitializer, !Matched::Int64) where T at boot.jl:406
#   ...
#
# Stacktrace:
#  [1] convert(::Type{Array{Float64,1}}, ::Array{Float64,2}) at .\array.jl:554
#  [2] setindex!(::Array{Array{Float64,1},1}, ::Array{Float64,2}, ::Int64) at .\array.jl:847
#  [3] mybootstrap(::Type{T} where T, ::Array{Float64,2}, ::Int64, ::Array{Float64,1}; id::Nothing, data_args::Int64, get::typeof(coef), red::Nothing, key_args::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at C:\Users\thomas\Documents\GitHub\MyMethods\src\FUN\mybootstrap.jl:27
#  [4] top-level scope at In[24]:2
#  [5] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
#  [6] execute_code(::String, ::String) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:27
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\execute_request.jl:86
#  [8] #invokelatest#1 at .\essentials.jl:710 [inlined]
#  [9] invokelatest at .\essentials.jl:709 [inlined]
#  [10] eventloop(::ZMQ.Socket) at C:\Users\thomas\.julia\packages\IJulia\rWZ9e\src\eventloop.jl:8
#  [11] (::IJulia.var"#15#18")() at .\task.jl:356
